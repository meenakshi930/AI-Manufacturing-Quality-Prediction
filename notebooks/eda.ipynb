# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
# Out:
# Running cells with 'Python 3.13.13' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Users/MEENAKSHI GUPTA/AppData/Local/Microsoft/WindowsApps/python3.13.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# Change filename if needed
df = pd.read_csv("../data/raw/manufacturing_defects_sample.csv")

df.head()

# %%
print("Shape of dataset:", df.shape)
df.info()

# %%
df.describe()

# %%
print("Missing Values:\n", df.isnull().sum())

plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
TARGET = "defect"  # change if needed

plt.figure(figsize=(6,4))
sns.countplot(x=TARGET, data=df)
plt.title("Target Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

print("Class Distribution (Percentage):")
print(df[TARGET].value_counts(normalize=True))

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
df.hist(figsize=(14,10))
plt.suptitle("Feature Distributions")
plt.show()

# %%
# Use sample to avoid slow plotting
sns.pairplot(df.sample(200), hue=TARGET)
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=TARGET, y=col, data=df)
    plt.title(f"{col} vs {TARGET}")
    plt.show()

# %%
# Observations:

# 1. Dataset has (mention shape) rows and columns.
# 2. Missing values are minimal / present in some features.
# 3. Target variable shows (balanced / slight imbalance).
# 4. Some features show strong correlation with target.
# 5. Outliers are present in certain numerical features.
# 6. Feature distributions are mostly (normal / skewed).

# Conclusion:
# The dataset is suitable for machine learning after preprocessing.
